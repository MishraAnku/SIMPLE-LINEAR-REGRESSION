# %% [markdown]
# In \[1\]:
#
#     # importing libraries
#     # train test split is the method which does the data partion like splitting the
#     # dataset into 80/20 or other spliiting
#     # from model selection we are importing the train test split to split the
#     # dataset into 80/ 20 split or the other splits.
#     # from sklearn.linear_model import LinearRegression - here we need to create
#     # an object from this class
#     # mean squared error is the error component that is the actual - predictions
#     # if we are taking the mean squared error that means  we are taking the square of the
#     # error to get the mean of the error terms.
#     # it is one of the elements which is used to judge the accuracy of the model .
#     # matplotlib is used to create the visuals. it is basic library to create the 2d plots.
#     # plt is the nick name for matplotlib
#     # pandas is used for reading the data  in the python enviroment
#     # numpy is used to read the mathematical data in the dataset .
#     # train test split will randomly select the 80/ 20 data drom the dataset as per the
#     # split partion selected . 80 percent will be training data and 20 prcet is the testing data
#     # mean square error will give the  idea of the error component
#
#     from sklearn.model_selection import train_test_split
#     from sklearn.linear_model import LinearRegression
#     from sklearn.metrics import mean_squared_error
#     import matplotlib.pyplot as plt
#     import pandas as pd
#     import numpy as np
#
# In \[3\]:
#
#     # importing the data
#     #  pandas is used to read the data
#     # when we are passing the string values we  use the single or double codes
#     # we cannot mention the string values without the codes
#
#     data = pd.read_csv('housing.csv')
#
# In \[4\]:
#
#     # Finding the shape of the dataset
#     # when we use the function then we need to use the parenthesis
#     # shape is the attribute/ feature / characterstics
#
#     data.shape
#
#     # here we have 20640 rows and 10 attributes/variables
#
# Out\[4\]:
#
#     (20640, 10)
#
# In \[5\]:
#
#     # Checking the first few rows of the data
#     # here we are checking the 1st 6 rows of the dataset
#     # if we are not giving any values to the head then bydefault we will get the top 5 rows
#
#     data.head(6)
#
# Out\[5\]:
#
# |     | longitude | latitude | housing_median_age | total_rooms | total_bedrooms | population | households | median_income | median_house_value | ocean_proximity |
# |-----|-----------|----------|--------------------|-------------|----------------|------------|------------|---------------|--------------------|-----------------|
# | 0   | -122.23   | 37.88    | 41.0               | 880.0       | 129.0          | 322.0      | 126.0      | 8.3252        | 452600.0           | NEAR BAY        |
# | 1   | -122.22   | 37.86    | 21.0               | 7099.0      | 1106.0         | 2401.0     | 1138.0     | 8.3014        | 358500.0           | NEAR BAY        |
# | 2   | -122.24   | 37.85    | 52.0               | 1467.0      | 190.0          | 496.0      | 177.0      | 7.2574        | 352100.0           | NEAR BAY        |
# | 3   | -122.25   | 37.85    | 52.0               | 1274.0      | 235.0          | 558.0      | 219.0      | 5.6431        | 341300.0           | NEAR BAY        |
# | 4   | -122.25   | 37.85    | 52.0               | 1627.0      | 280.0          | 565.0      | 259.0      | 3.8462        | 342200.0           | NEAR BAY        |
# | 5   | -122.25   | 37.85    | 52.0               | 919.0       | 213.0          | 413.0      | 193.0      | 4.0368        | 269700.0           | NEAR BAY        |
#
# In \[6\]:
#
#     # printing the rows from the bottom of the dataset
#     # if we are not giving anay value to display in the bottom bydefault bottom 5 values will be
#     # displayed .
#     # intrinsic headers do not have headers . it is automatically alinged
#
#     data.tail()
#
# Out\[6\]:
#
# |       | longitude | latitude | housing_median_age | total_rooms | total_bedrooms | population | households | median_income | median_house_value | ocean_proximity |
# |-------|-----------|----------|--------------------|-------------|----------------|------------|------------|---------------|--------------------|-----------------|
# | 20635 | -121.09   | 39.48    | 25.0               | 1665.0      | 374.0          | 845.0      | 330.0      | 1.5603        | 78100.0            | INLAND          |
# | 20636 | -121.21   | 39.49    | 18.0               | 697.0       | 150.0          | 356.0      | 114.0      | 2.5568        | 77100.0            | INLAND          |
# | 20637 | -121.22   | 39.43    | 17.0               | 2254.0      | 485.0          | 1007.0     | 433.0      | 1.7000        | 92300.0            | INLAND          |
# | 20638 | -121.32   | 39.43    | 18.0               | 1860.0      | 409.0          | 741.0      | 349.0      | 1.8672        | 84700.0            | INLAND          |
# | 20639 | -121.24   | 39.37    | 16.0               | 2785.0      | 616.0          | 1387.0     | 530.0      | 2.3886        | 89400.0            | INLAND          |
#
# In \[7\]:
#
#     # finding the relationship between median_income and median_house value
#     # here we are 2 variables that is median income and the median house value
#     # this 2 variables are interlated as if the income is high the person will buy more expensive
#     # house and if teh income is low the person will buy less expensive house .
#     # matplotlib library is having the plot function
#     # here we are plotting the 2 variables from the data
#     # plot. show is used to show the line plot
#     # plt.show() this command is used to get the permanent output .
#
#     data.plot("median_income","median_house_value")
#     plt.show()
#
# ![](data:image/png;base64,...%0A)
#
# ## The graph is difficult to comprehend. To make the relationship clear,we go for scatterplots<a href="#The-graph-is-difficult-to-comprehend.-To-make-the-relationship-clear,we-go-for-scatterplots" class="anchor-link">¶</a>
#
# In \[10\]:
#
#     # plotting the scatter plot
#     #  here we are plotting the scatter plot from the data for the 2 variables
#     # plt.show() - it is used to plot the scatter plot and to get the permanent output .
#
#     data.plot.scatter("median_income","median_house_value")
#     plt.show()
#
#     #  OBSERVATIONS
#     # the 2 variables are positively correlated
#     # as the income increases the house value also increases
#     # there is the positive correlation among the 2 variables
#
# ![](data:image/png;base64,...%0A)
#
# In \[11\]:
#
#     # here we have created the variable called x1 for x train data
#     # name of the dataframe is given as data and selected the median income option
#
#     x1 = data["median_income"]
#
# In \[12\]:
#
#     # x is the independent variable
#     # checking the shape of the x train set
#     x1.shape
#
# Out\[12\]:
#
#     (20640,)
#
# In \[13\]:
#
#     # here we have created the variable called y1 for x train data
#     # name of the dataframe is given as data and selected the median house value option
#
#     y1 = data["median_house_value"]
#
# In \[14\]:
#
#     # x is the dependent variable
#     # checking the shape of the y train set
#
#     y1.shape
#
# Out\[14\]:
#
#     (20640,)
#
# In \[15\]:
#
#     # creating an object from the linear regression class
#     # here we have created the variable called regmodel
#     # take care about the capital and the small letters
#
#     regmodel=LinearRegression()
#
# ## Say you have an array of shape (2,6) then reshaping it with (-1,1) will give you a resulting array having 1 column only now it can have 12 rows (as we do not explicitely mention the dimension for conversion).<a href="#Say-you-have-an-array-of-shape-(2,6)-then-reshaping-it-with-(-1,1)-will-give-you-a-resulting-array-having-1-column-only-now-it-can-have-12-rows-(as-we-do-not-explicitely-mention-the-dimension-for-conversion)." class="anchor-link">¶</a>
#
# ## The resulting array will have a shape of (12,1)<a href="#The-resulting-array-will-have-a-shape-of-(12,1)" class="anchor-link">¶</a>
#
# ### As per the plot,we see a strong positive correlation among the two variables<a href="#As-per-the-plot,we-see-a-strong-positive-correlation-among-the-two-variables" class="anchor-link">¶</a>
#
# In \[ \]:
#
#     #  when we are talking about the simple linear regression model we have only have 2 variables
#     #  1st is indepenedent variable X
#     #  second is the dependent variable Y
#
# In \[14\]:
#
#     # splitting the data
#     #  we are splitting the data into the 4 subsets  that is X_train,X_test,y_train,y_test
#     #  then we are using the train test split
#     # then we are taking the 2 variables from the data by giving the test size of 0.25
#     # 0.2 means splitting the data into the 80 , 20 split
#     # 0.3 means splitting the data into 70 , 30 split
#     # 0.25 means splitting the data into the 75 , 25 split
#     # X_train,X_test,y_train,y_test=train_test_split
#     # (data.median_income,data.median_house_value,test_size=0.25)
#     # here we have not given the random state that means everytime we will run the
#     # code the values will be differ
#     # we will get the different results because the data will be partioned in 80/ 20 split randomly
#
# In \[15\]:
#
#     x_train,x_test, y_train,y_test = train_test_split
#     (data.median_income,data.median_house_value,test_size=0.2)
#
#     # independent variable X - median_income
#     # dependent variable Y- median_house_value
#
# In \[17\]:
#
#     # here we have created the x train
#     # the input and the output data should be in the form of array so that we can
#     # apply any kind of functions on the array
#
#     x_train
#
# Out\[17\]:
#
#     11507    4.6369
#     13243    8.4839
#     7445     4.7708
#     19622    4.0000
#     7858     2.9292
#               ...
#     12768    1.3696
#     15       2.1250
#     13521    5.2072
#     7714     5.0526
#     17466    5.4197
#     Name: median_income, Length: 16512, dtype: float64
#
# In \[18\]:
#
#     # here we have the y train
#     # whenever we have created the dataframe with pandas the intrinsic indexes are automatically alinghed
#     # this indexes are automatically given by the pandas .
#     y_train
#
# Out\[18\]:
#
#     11507    422200.0
#     13243    406700.0
#     7445     178600.0
#     19622     75000.0
#     7858     183400.0
#                ...
#     12768     65200.0
#     15       140000.0
#     13521    164300.0
#     7714     269800.0
#     17466    280900.0
#     Name: median_house_value, Length: 16512, dtype: float64
#
# In \[19\]:
#
#     #creating an object from the linearregression class
#     regmodel=LinearRegression()
#
# In \[20\]:
#
#     # training the model
#     # # here are going to train the model and make it predict with the test set
#     # here we are training the model
#     # here we are fitting the linear rehression model
#     # when we train the regression model we use the train data
#     # here we will use the x train , y train to train the data
#     # when we train the model we need to give the value for the independent variable and the
#     # dependent variable
#     # questions are the independent variable and the answer is dependent variable
#     # numpy package gives the array function with which we can create the multidimenssional array
#     # here we have converted both the input / output in the form of an array
#
# In \[21\]:
#
#     # converting the x train data into an array
#     # then we reshape the yy train data
#     # y train is the 1d data
#     # reshape function is used when we want to chnage the shape of the particular object
#     # as we can chnage the dimession of the data and if the x train / y train appears vertically
#     # we can chnage it to display the elements as horizontally
#     # using the reshape function only for the y train data
#     # -1 means it is the unknown dimenssion that means we want the y train data to be converted
#     # into the inknown dimenssion
#     # -1 is used either we can choose the x axis or the y axis  / either arranged it vertically or
#     # horizontally but it should be 1d
#     # (-1,1) - this means we will rehshape our data into different dimenssion that is reshaping the
#     # y train data
#     # we are chnaging the shape of the y train data but the original y train data will be same .
#     # but here when we are fitting the y train data the y train data is in the different format
#     # we can convert the matrix horizontally and vertically in any manner but we need to take care
#     # that the total number of elements should be same
#
#     # here we are fitting the x train set converted into the numpy array and reshaping the y train
#     # set into any other dimenssions into the variable called the regression model
#
#     regmodel.fit(np.array(x_train).reshape(-1,1),y_train)
#
# Out\[21\]:
#
#     LinearRegression()
#
# **In a Jupyter environment, please rerun this cell to show the HTML
# representation or trust the notebook.
# On GitHub, the HTML representation is unable to render, please try
# loading this page with nbviewer.org.**
#
# LinearRegression
#
#     LinearRegression()
#
# In \[22\]:
#
#     ## Reshape is being applied to change the y_train data to change it from pandas to numpy,
#     # in the form of a vector of values.
#     ## This function transforms a single dimension matrix to a vertical shape
#     ## array are usually the matrixes
#
# In \[23\]:
#
#     # here we are creating the prediction
#     # we are building the models to generate the predictions
#     # the variable we have created before is the regmodel
#     # we are generating the predictions using the predict function
#     # by using the numpy array in the x test and reshaoing it
#     # here we are having  1 column that is x test so converting it into the 1d
#
#     preds = regmodel.predict(np.array(x_test).reshape(-1,1))
#
# In \[24\]:
#
#     # checking the 1st few actual values of y test set
#     10653
#     115
#     6163
#     9186
#     3256
#     # this are the intrinsic index which are automatically generated
#
#     y_test.head()
#
# Out\[24\]:
#
#     10653    194400.0
#     115      231600.0
#     6163     187700.0
#     9186     323300.0
#     3256      71300.0
#     Name: median_house_value, dtype: float64
#
# In \[25\]:
#
#     # here we are checking the predictions for these y test actual values
#     # preds is the function to check for the predictions
#
#     preds
#
# Out\[25\]:
#
#     array([247629.91534184, 176350.63667661, 248515.73555856, ...,
#            172305.94813988, 239147.76892702, 201379.2361962 ])
#
# In \[ \]:
#
#     # what is the basic assumption of the classical linear regression model
#     # it should always follows the standard normal distribution  with the mean of 0 and
#     # the standard deviation of 1. the error terms should be independent
#     # this is one of the assumption
#     # there are various assumptions like ;
#     # the independent variables should be related to each other
#     # the error terms assosiated with each of the independent variables should also not be related .
#     # it should be independent
#     # the elements are independent means the variables do not have the relationship among the variables
#     # error terms are independent - this means error terms with each independent variables should not
#     # have nay mutual relationship among themseleves
#
# In \[26\]:
#
#     # what are the error componenets
#     # the error component are called as the residuals of the error  that is the actual - predictive
#     # finding the error in predictions
#     # here we have created the variable called errors
#     # here we are predicting the errors in the y test
#
#     errors = preds-y_test
#
# In \[27\]:
#
#     # plotting a histogram of the errors
#     # for plotting the histogram we used  the hist function
#     # here we are plotting the histogram for errors
#     # plt.show() - it is used to get the permanenet output
#
#     plt.hist(errors)
#     plt.show()
#
#     # it is not the normal distribution
#     #
#
# <img src="data:image/png;base64,...%0A" class="jp-needs-light-background" />
#
# In \[28\]:
#
#     # finding the accuracy square
#     # if the mean squared square is low then the model is good or if the mean squared is high the model
#     # is not good but it does not give the significant score
#     # so here we are importing r2 score from the sklearn . metrices
#     # here we have created the variable called r square
#     # then by using the r2_score we are checking the difference between the y test and the predictions
#     # that how good the model is
#     #  then we will print the r square
#     # here we are using the y test because y test stores values of the price of the house that is the
#     # response / dependent variables
#     # total x set contains the mean income values and y in total contains the house price then we divide
#     # the set into training and the testing set
#
#     from sklearn.metrics import r2_score
#     r2 = r2_score(y_test, preds)
#     print(r2)
#
#     # here the observation is ;
#     # accuracy is 46 percent which is very bad model
#     # atleats the model should have the accuracy above 60 percent then it is counted as the good model
#
#     0.4649806067230595
#
# In \[ \]:
#
#     # r square  - in the linear regression model r2 explains that how mch the model is fit .
#     # how well the regression model fits the actual observations .
#     # if the model is giid fit the r2 value will be high
#     # r square is called as the coeffeicient of determination.
#     # it is the standard metric used to judge  the fit of your model that means how fit the model is .
#     # it gives the idea that how good the model we are building
#     # if the midel is a proper fit to all the actual values means in other terms
#     # if the predictions are very close to the actual values  that is captured by the metric r square
#     # it just compare the predictions with the actual values
#     # if the predictions are close to the actual values  the model is predicting very well
#     # so we will get the  higher r square
#      # chi- square - it is the non - parametric test .it is applied to the categrical values .
#     # it is used for the hypothesis testing . it is not related to the model
#     # what is mean squared error
#     # it basically gives the errors between the predictions and the actual values.
#     # it gives the idea that how bad the model is
#     # if the mean squared error is low that means there is less deviation between the actual
#     # and the predicted values
#
#     # adjacent r square - it is the modified version of the r squared that has been adjusted
#     # for the numbers of predictors in the model .
#
# In \[ \]:
#
#
#
# In \[ \]:
